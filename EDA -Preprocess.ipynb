# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100)

# %%
df = pd.read_csv("train.csv")

# %%
df.head(2)
# Out:
#    ID  target        v1        v2 v3        v4        v5        v6        v7        v8        v9  \
# 0   3       1  1.335739  8.727474  C  3.921026  7.915266  2.599278  3.176895  0.012941  9.999999
# 1   4       1       NaN       NaN  C       NaN  9.191265       NaN       NaN  2.301630       NaN
#
#         v10        v11       v12      v13        v14       v15       v16      v17      v18  \
# 0  0.503281  16.434108  6.085711  2.86683  11.636387  1.355013  8.571429  3.67035  0.10672
# 1  1.312910        NaN  6.507647      NaN  11.636386       NaN       NaN      NaN      NaN
#
#         v19        v20       v21  v22           v23 v24       v25       v26       v27       v28  \
# 0  0.148883  18.869283  7.730923  XDX -1.716131e-08   C  0.139412  1.720818  3.393503  0.590122
# 1       NaN        NaN  6.763110  GUV           NaN   C  3.056144       NaN       NaN       NaN
#
#         v29 v30 v31       v32       v33       v34       v35        v36       v37  v38       v39  \
# ...

# %%
selected_features = ['ID','target','v4', 'v6', 'v9', 'v10', 'v12', 'v14', 'v16',
              'v18', 'v19', 'v21', 'v34', 'v36', 'v38', 'v39',
              'v40', 'v45', 'v50', 'v53', 'v57', 'v58',
              'v62', 'v68', 'v69', 'v72', 'v80', 'v81',
              'v82', 'v85', 'v88', 'v90',
              'v93', 'v98', 'v99', 'v100', 'v114', 'v115',
              'v119', 'v120', 'v123', 'v124', 'v127', 'v129', 'v22',
              'v24', 'v30', 'v31', 'v47', 'v52', 'v56', 'v66',
              'v71', 'v75', 'v79', 'v112', 'v113', 'v125']

# %%
df = df[selected_features]

# %%
df[selected_features].info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114321 entries, 0 to 114320
# Data columns (total 58 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      114321 non-null  int64
#  1   target  114321 non-null  int64
#  2   v4      64525 non-null   float64
#  3   v6      64489 non-null   float64
#  4   v9      64470 non-null   float64
#  5   v10     114237 non-null  float64
#  6   v12     114235 non-null  float64
#  7   v14     114317 non-null  float64
#  8   v16     64426 non-null   float64
#  9   v18     64489 non-null   float64
#  10  v19     64478 non-null   float64
#  11  v21     113710 non-null  float64
#  12  v34     114210 non-null  float64
#  13  v36     65697 non-null   float64
#  14  v38     114321 non-null  int64
#  15  v39     64485 non-null   float64
#  16  v40     114210 non-null  float64
#  17  v45     64489 non-null   float64
#  18  v50     114235 non-null  float64
#  19  v53     64485 non-null   float64
# ...

# %%
int_cols = df.select_dtypes(include=np.number).columns
int_cols
# Out:
# Index(['ID', 'target', 'v4', 'v6', 'v9', 'v10', 'v12', 'v14', 'v16', 'v18', 'v19', 'v21', 'v34',
#        'v36', 'v38', 'v39', 'v40', 'v45', 'v50', 'v53', 'v57', 'v58', 'v62', 'v68', 'v69', 'v72',
#        'v80', 'v81', 'v82', 'v85', 'v88', 'v90', 'v93', 'v98', 'v99', 'v100', 'v114', 'v115',
#        'v119', 'v120', 'v123', 'v124', 'v127', 'v129'],
#       dtype='object')

# %%
df[int_cols].isna().sum()
# Out:
# ID            0
# target        0
# v4        49796
# v6        49832
# v9        49851
# v10          84
# v12          86
# v14           4
# v16       49895
# v18       49832
# v19       49843
# v21         611
# v34         111
# v36       48624
# v38           0
# v39       49836
# v40         111
# v45       49832
# v50          86
# v53       49836
# v57       49832
# v58       49836
# v62           0
# v68       49836
# v69       49895
# v72           0
# v80       49851
# v81       48624
# v82       48624
# v85       50682
# v88       49832
# v90       49836
# v93       49832
# v98       48654
# v99       49832
# v100      49836
# v114         30
# v115      49895
# v119      50680
# v120      49836
# v123      50678
# v124      48619
# v127      49832
# v129          0
# dtype: int64

# %%
cat_cols = df.select_dtypes(exclude=np.number).columns
cat_cols
# Out:
# Index(['v22', 'v24', 'v30', 'v31', 'v47', 'v52', 'v56', 'v66', 'v71', 'v75', 'v79', 'v112', 'v113',
#        'v125'],
#       dtype='object')

# %%
df[cat_cols].isna().sum()
# Out:
# v22       500
# v24         0
# v30     60110
# v31      3457
# v47         0
# v52         3
# v56      6882
# v66         0
# v71         0
# v75         0
# v79         0
# v112      382
# v113    55304
# v125       77
# dtype: int64

# %%
cat_cols[df[cat_cols].isna().sum() > 0 ]
# Out:
# Index(['v22', 'v30', 'v31', 'v52', 'v56', 'v112', 'v113', 'v125'], dtype='object')

# %%
df[cat_cols].head()
# Out:
#     v22 v24  v30 v31 v47 v52  v56 v66 v71 v75 v79 v112 v113 v125
# 0   XDX   C    C   A   C   G   DI   C   F   D   E    O  NaN   AU
# 1   GUV   C    C   A   E   G   DY   A   F   D   D    U    G   AF
# 2    FQ   E  NaN   A   C   F   AS   A   B   B   E    S  NaN   AE
# 3  ACUE   D    C   B   C   H   BW   A   F   D   B    J  NaN   CJ
# 4   HIT   E  NaN   A   I   H  NaN   C   F   D   C    T    G    Z

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['v22'].value_counts(dropna=False)
# Out:
# AGDF    2386
# YGJ     2119
# QKI      668
# PWR      649
# NaN      500
#         ...
# UXG        1
# NKC        1
# BHZ        1
# ACSQ       1
# ODT        1
# Name: v22, Length: 18211, dtype: int64
